# %%
import pandas as pd

# %%
df1 = pd.read_csv("hotels_RoomPrice.csv")
df2 = pd.read_csv("Hotel_Room_attributes.csv")

df_merge1 = df1.merge(df2, left_on = 'hotelcode', right_on = 'hotelcode')

# c = pd.read_csv("hotel_price_min_max - Formula.csv")
# d = pd.read_csv("hotels_RoomPrice.csv")

# %%
df_merge1
# Out:
#              id_x    refid  hotelcode  websitecode  ratedate  los  guests  \
# 0        50677497  8646773     634876            5  02/11/19    1       1
# 1        50677497  8646773     634876            5  02/11/19    1       1
# 2        50677497  8646773     634876            5  02/11/19    1       1
# 3        50677497  8646773     634876            5  02/11/19    1       1
# 4        50677497  8646773     634876            5  02/11/19    1       1
# ...           ...      ...        ...          ...       ...  ...     ...
# 9032756  88475970  8022722    6592926            5  17/10/19    1       1
# 9032757  88475970  8022722    6592926            5  17/10/19    1       1
# 9032758  88475970  8022722    6592926            5  17/10/19    1       1
# 9032759  88475970  8022722    6592926            5  17/10/19    1       1
# 9032760  88475970  8022722    6592926            5  17/10/19    1       1
#
#                                         roomtype_x  onsiterate  netrate  ...  \
# ...

# %% [markdown]
# **NOTE:**
# I think this data should be enough for the project.
# i tried to merge all the .csv's but it not working properly ie;Data is not connected correctly  so, im thinking this should be fine.

# %%
df_merge1.to_csv("df_out1.csv", index= False )

# %%
df3 = pd.read_csv("Hotel_details.csv")
# df3 = pd.read_csv("hotel_price_min_max - Formula.csv")

df_merge2 = df_merge1.merge(df3, left_on = 'hotelcode', right_on = 'hotelcode')

# %%
df_merge2.to_csv("df_OutFinal.csv", index= False )
